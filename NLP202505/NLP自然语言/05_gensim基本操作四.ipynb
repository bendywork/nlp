# %%
from gensim.test.utils import common_texts
print(common_texts)
# Out:
# [['human', 'interface', 'computer'], ['survey', 'user', 'computer', 'system', 'response', 'time'], ['eps', 'user', 'interface', 'system'], ['system', 'human', 'system', 'eps'], ['user', 'response', 'time'], ['trees'], ['graph', 'trees'], ['graph', 'minors', 'trees'], ['graph', 'minors', 'survey']]

# %% [markdown]
# # 一、Doc2Vec

# %%
from gensim.test.utils import common_texts
from gensim.models.doc2vec import Doc2Vec, TaggedDocument

# %%
# 拼接数据
documents = [TaggedDocument(doc, [i]) for i,doc in enumerate(common_texts)]
# 模型训练 --> 针对每个单词训练好对应的单词向量以及结构中的决策分类相关的特征向量
model = Doc2Vec(documents, vector_size=5, window=2, min_count=1, workers=3)

# %%
# 预测文本对应向量的时候，实际上是基于训练好的单词向量(冻结固定)，然后反向传播更新待预测文本/文档对应的特征向量
vector = model.infer_vector(["system", "response"])
print("【Doc2Vec结果】:\n{}".format(vector))
# Out:
# 【Doc2Vec结果】:
# [ 0.08525846 -0.0457656  -0.03891642 -0.06006378 -0.01335535]

# %% [markdown]
# # 二、FastText

# %%
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
from gensim import utils
from gensim.models.fasttext import FastText

word_file_path = './datas/cut_words_of_in_the_name_of_people.txt'
class MyData(object):
    def __iter__(self):
        path = word_file_path
        with open(path, 'r', encoding='utf-8') as reader:
            for line in reader:
                yield list(utils.tokenize(line))

# 模型构建
model = FastText(vector_size=4, window=3, min_count=1, sentences=MyData(), epochs=10)
# Out:
# 2025-07-19 14:55:12,377 : INFO : collecting all words and their counts
# 2025-07-19 14:55:12,381 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2025-07-19 14:55:12,481 : INFO : collected 17807 word types from a corpus of 131946 raw words and 2421 sentences
# 2025-07-19 14:55:12,481 : INFO : Creating a fresh vocabulary
# 2025-07-19 14:55:12,521 : INFO : FastText lifecycle event {'msg': 'effective_min_count=1 retains 17807 unique words (100.00% of original 17807, drops 0)', 'datetime': '2025-07-19T14:55:12.521708', 'gensim': '4.3.3', 'python': '3.12.9 | packaged by Anaconda, Inc. | (main, Feb  6 2025, 18:49:16) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-11-10.0.22631-SP0', 'event': 'prepare_vocab'}
# 2025-07-19 14:55:12,523 : INFO : FastText lifecycle event {'msg': 'effective_min_count=1 leaves 131946 word corpus (100.00% of original 131946, drops 0)', 'datetime': '2025-07-19T14:55:12.523017', 'gensim': '4.3.3', 'python': '3.12.9 | packaged by Anaconda, Inc. | (main, Feb  6 2025, 18:49:16) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-11-10.0.22631-SP0', 'event': 'prepare_vocab'}
# 2025-07-19 14:55:12,601 : INFO : deleting the raw counts dictionary of 17807 items
# 2025-07-19 14:55:12,604 : INFO : sample=0.001 downsamples 40 most-common words
# 2025-07-19 14:55:12,605 : INFO : FastText lifecycle event {'msg': 'downsampling leaves estimated 111166.60739376978 word corpus (84.3%% of prior 131946)', 'datetime': '2025-07-19T14:55:12.605436', 'gensim': '4.3.3', 'python': '3.12.9 | packaged by Anaconda, Inc. | (main, Feb  6 2025, 18:49:16) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-11-10.0.22631-SP0', 'event': 'prepare_vocab'}
# 2025-07-19 14:55:12,729 : INFO : estimated required memory for 17807 words, 2000000 buckets and 4 dimensions: 43549116 bytes
# 2025-07-19 14:55:12,730 : INFO : resetting layer weights
# 2025-07-19 14:55:12,908 : INFO : FastText lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2025-07-19T14:55:12.908522', 'gensim': '4.3.3', 'python': '3.12.9 | packaged by Anaconda, Inc. | (main, Feb  6 2025, 18:49:16) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-11-10.0.22631-SP0', 'event': 'build_vocab'}
# 2025-07-19 14:55:12,909 : INFO : FastText lifecycle event {'msg': 'training model with 3 workers on 17807 vocabulary and 4 features, using sg=0 hs=0 sample=0.001 negative=5 window=3 shrink_windows=True', 'datetime': '2025-07-19T14:55:12.909525', 'gensim': '4.3.3', 'python': '3.12.9 | packaged by Anaconda, Inc. | (main, Feb  6 2025, 18:49:16) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-11-10.0.22631-SP0', 'event': 'train'}
# 2025-07-19 14:55:13,055 : INFO : EPOCH 0: training on 131946 raw words (110900 effective words) took 0.1s, 777717 effective words/s
# 2025-07-19 14:55:13,203 : INFO : EPOCH 1: training on 131946 raw words (110993 effective words) took 0.1s, 761780 effective words/s
# 2025-07-19 14:55:13,354 : INFO : EPOCH 2: training on 131946 raw words (111141 effective words) took 0.1s, 749409 effective words/s
# 2025-07-19 14:55:13,545 : INFO : EPOCH 3: training on 131946 raw words (111146 effective words) took 0.2s, 602707 effective words/s
# 2025-07-19 14:55:13,743 : INFO : EPOCH 4: training on 131946 raw words (111163 effective words) took 0.2s, 571584 effective words/s
# 2025-07-19 14:55:13,934 : INFO : EPOCH 5: training on 131946 raw words (110986 effective words) took 0.2s, 598923 effective words/s
# 2025-07-19 14:55:14,091 : INFO : EPOCH 6: training on 131946 raw words (111281 effective words) took 0.2s, 718869 effective words/s
# 2025-07-19 14:55:14,265 : INFO : EPOCH 7: training on 131946 raw words (111270 effective words) took 0.2s, 646776 effective words/s
# 2025-07-19 14:55:14,430 : INFO : EPOCH 8: training on 131946 raw words (111195 effective words) took 0.2s, 686182 effective words/s
# 2025-07-19 14:55:14,590 : INFO : EPOCH 9: training on 131946 raw words (111176 effective words) took 0.2s, 718730 effective words/s
# 2025-07-19 14:55:14,591 : INFO : FastText lifecycle event {'msg': 'training on 1319460 raw words (1111251 effective words) took 1.7s, 661223 effective words/s', 'datetime': '2025-07-19T14:55:14.591242', 'gensim': '4.3.3', 'python': '3.12.9 | packaged by Anaconda, Inc. | (main, Feb  6 2025, 18:49:16) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-11-10.0.22631-SP0', 'event': 'train'}
# 2025-07-19 14:55:14,695 : INFO : FastText lifecycle event {'params': 'FastText<vocab=17807, vector_size=4, alpha=0.025>', 'datetime': '2025-07-19T14:55:14.695451', 'gensim': '4.3.3', 'python': '3.12.9 | packaged by Anaconda, Inc. | (main, Feb  6 2025, 18:49:16) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-11-10.0.22631-SP0', 'event': 'created'}

# %%
# 夹角余弦相似度
req_count = 5
for key in model.wv.similar_by_word('沙瑞金', topn =100):
    if len(key[0])==3:
        req_count -= 1
        print(key[0], key[1])
        if req_count == 0:
            break;
# Out:
# 请育良 0.9990583062171936
# 有事吗 0.9989035725593567
# 东南亚 0.9984809160232544
# 找育良 0.9983877539634705
# 有多近 0.9983347058296204
