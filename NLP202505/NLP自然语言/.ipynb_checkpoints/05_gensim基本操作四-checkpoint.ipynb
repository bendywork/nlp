# %%
from gensim.test.utils import common_texts
print(common_texts)
# Out:
# [['human', 'interface', 'computer'], ['survey', 'user', 'computer', 'system', 'response', 'time'], ['eps', 'user', 'interface', 'system'], ['system', 'human', 'system', 'eps'], ['user', 'response', 'time'], ['trees'], ['graph', 'trees'], ['graph', 'minors', 'trees'], ['graph', 'minors', 'survey']]

# %% [markdown]
# # 一、Doc2Vec

# %%
from gensim.test.utils import common_texts
from gensim.models.doc2vec import Doc2Vec, TaggedDocument

# %%
# 拼接数据
documents = [TaggedDocument(doc, [i]) for i,doc in enumerate(common_texts)]
# 模型训练
model = Doc2Vec(documents, vector_size=5, window=2, min_count=1, workers=3)

# %%
# 预测文本对应向量的时候，实际上是基于训练好的单词向量(冻结固定)，然后反向传播更新待预测文本/文档对应的特征向量
vector = model.infer_vector(["system", "response"])
print("【Doc2Vec结果】:\n{}".format(vector))
# Out:
# 【Doc2Vec结果】:
# [ 0.08442415  0.00964168 -0.03172302 -0.07696461 -0.04324263]

# %% [markdown]
# # 二、FastText

# %%
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
from gensim import utils
from gensim.models.fasttext import FastText

word_file_path = './datas/cut_words_of_in_the_name_of_people.txt'
class MyData(object):
    def __iter__(self):
        path = word_file_path
        with open(path, 'r', encoding='utf-8') as reader:
            for line in reader:
                yield list(utils.tokenize(line))

# 模型构建
model = FastText(vector_size=4, window=3, min_count=1, sentences=MyData(), epochs=10)
# Out:
# 2025-01-10 23:28:14,214 : INFO : collecting all words and their counts
# 2025-01-10 23:28:14,214 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2025-01-10 23:28:14,285 : INFO : collected 17738 word types from a corpus of 131863 raw words and 2421 sentences
# 2025-01-10 23:28:14,285 : INFO : Creating a fresh vocabulary
# 2025-01-10 23:28:14,322 : INFO : FastText lifecycle event {'msg': 'effective_min_count=1 retains 17738 unique words (100.00% of original 17738, drops 0)', 'datetime': '2025-01-10T23:28:14.322095', 'gensim': '4.2.0', 'python': '3.8.19 (default, Mar 20 2024, 19:55:45) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'prepare_vocab'}
# 2025-01-10 23:28:14,322 : INFO : FastText lifecycle event {'msg': 'effective_min_count=1 leaves 131863 word corpus (100.00% of original 131863, drops 0)', 'datetime': '2025-01-10T23:28:14.322095', 'gensim': '4.2.0', 'python': '3.8.19 (default, Mar 20 2024, 19:55:45) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'prepare_vocab'}
# 2025-01-10 23:28:14,377 : INFO : deleting the raw counts dictionary of 17738 items
# 2025-01-10 23:28:14,377 : INFO : sample=0.001 downsamples 40 most-common words
# 2025-01-10 23:28:14,377 : INFO : FastText lifecycle event {'msg': 'downsampling leaves estimated 111056.0714298438 word corpus (84.2%% of prior 131863)', 'datetime': '2025-01-10T23:28:14.377088', 'gensim': '4.2.0', 'python': '3.8.19 (default, Mar 20 2024, 19:55:45) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'prepare_vocab'}
# 2025-01-10 23:28:14,480 : INFO : estimated required memory for 17738 words, 2000000 buckets and 4 dimensions: 43503620 bytes
# 2025-01-10 23:28:14,480 : INFO : resetting layer weights
# 2025-01-10 23:28:14,636 : INFO : FastText lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2025-01-10T23:28:14.636229', 'gensim': '4.2.0', 'python': '3.8.19 (default, Mar 20 2024, 19:55:45) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'build_vocab'}
# 2025-01-10 23:28:14,636 : INFO : FastText lifecycle event {'msg': 'training model with 3 workers on 17738 vocabulary and 4 features, using sg=0 hs=0 sample=0.001 negative=5 window=3 shrink_windows=True', 'datetime': '2025-01-10T23:28:14.636992', 'gensim': '4.2.0', 'python': '3.8.19 (default, Mar 20 2024, 19:55:45) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'train'}
# 2025-01-10 23:28:14,734 : INFO : EPOCH 0: training on 131863 raw words (111095 effective words) took 0.1s, 1156506 effective words/s
# 2025-01-10 23:28:14,845 : INFO : EPOCH 1: training on 131863 raw words (111037 effective words) took 0.1s, 1029316 effective words/s
# 2025-01-10 23:28:14,955 : INFO : EPOCH 2: training on 131863 raw words (111009 effective words) took 0.1s, 1061932 effective words/s
# 2025-01-10 23:28:15,045 : INFO : EPOCH 3: training on 131863 raw words (110992 effective words) took 0.1s, 1200549 effective words/s
# 2025-01-10 23:28:15,141 : INFO : EPOCH 4: training on 131863 raw words (111045 effective words) took 0.1s, 1242716 effective words/s
# 2025-01-10 23:28:15,260 : INFO : EPOCH 5: training on 131863 raw words (111052 effective words) took 0.1s, 954095 effective words/s
# 2025-01-10 23:28:15,361 : INFO : EPOCH 6: training on 131863 raw words (111012 effective words) took 0.1s, 1091529 effective words/s
# 2025-01-10 23:28:15,451 : INFO : EPOCH 7: training on 131863 raw words (110959 effective words) took 0.1s, 1209289 effective words/s
# 2025-01-10 23:28:15,558 : INFO : EPOCH 8: training on 131863 raw words (110977 effective words) took 0.1s, 1115438 effective words/s
# 2025-01-10 23:28:15,667 : INFO : EPOCH 9: training on 131863 raw words (111051 effective words) took 0.1s, 1066662 effective words/s
# 2025-01-10 23:28:15,667 : INFO : FastText lifecycle event {'msg': 'training on 1318630 raw words (1110229 effective words) took 1.0s, 1077694 effective words/s', 'datetime': '2025-01-10T23:28:15.667286', 'gensim': '4.2.0', 'python': '3.8.19 (default, Mar 20 2024, 19:55:45) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'train'}
# 2025-01-10 23:28:15,737 : INFO : FastText lifecycle event {'params': 'FastText<vocab=17738, vector_size=4, alpha=0.025>', 'datetime': '2025-01-10T23:28:15.737647', 'gensim': '4.2.0', 'python': '3.8.19 (default, Mar 20 2024, 19:55:45) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'created'}

# %%
# 夹角余弦相似度
req_count = 5
for key in model.wv.similar_by_word('沙瑞金', topn =100):
    if len(key[0])==3:
        req_count -= 1
        print(key[0], key[1])
        if req_count == 0:
            break;
# Out:
# 点达康 0.999431312084198
# 记不清 0.9993440508842468
# 老季定 0.9992116689682007
# 怎么样 0.9989835619926453
# 是不是 0.9989790320396423
