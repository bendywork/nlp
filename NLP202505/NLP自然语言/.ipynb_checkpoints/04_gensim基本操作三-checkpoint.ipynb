# %%
# import modules & set up logging
import logging
import os

import numpy as np

import gensim
from gensim.models import word2vec

import jieba.analyse
import jieba

# %%
# set up logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
sentence_file_path = './datas/in_the_name_of_people.txt'
word_file_path = './datas/cut_words_of_in_the_name_of_people.txt'
model_file_path1 = './datas/gensim_word2vec1.w2v'
model_file_path2 = './datas/gensim_word2vec2.bin'
model_file_path3 = './datas/gensim_word2vec3_{}.npy'

# %% [markdown]
# ## 一、分词

# %%
# 人民的名义 小说分词
jieba.suggest_freq('沙瑞金',True)
jieba.suggest_freq('田国富',True)
jieba.suggest_freq('高育良',True)
jieba.suggest_freq('侯亮平',True)
jieba.suggest_freq('钟小艾', True)
jieba.suggest_freq('陈岩石', True)
jieba.suggest_freq('欧阳菁', True)
jieba.suggest_freq('易学习', True)
jieba.suggest_freq('王大路', True)
jieba.suggest_freq('蔡成功', True)
jieba.suggest_freq('孙连城', True)
jieba.suggest_freq('季昌明', True)
jieba.suggest_freq('丁义珍', True)
jieba.suggest_freq('郑西坡', True)
jieba.suggest_freq('赵东来', True)
jieba.suggest_freq('高小琴', True)
jieba.suggest_freq('赵瑞龙', True)
jieba.suggest_freq('林华华', True)
jieba.suggest_freq('陆亦可', True)
jieba.suggest_freq('刘新建', True)
jieba.suggest_freq('刘庆祝', True)
jieba.suggest_freq('京州市', True)
jieba.suggest_freq('副市长', True)
jieba.suggest_freq('赵德汉',True)
jieba.suggest_freq('H大学',True)
jieba.suggest_freq('H省',True)
jieba.suggest_freq('政法系', True)

with open(word_file_path,'w', encoding='utf-8') as writer:
    with open(sentence_file_path, 'r', encoding='utf-8') as reader:
        # 加载所有数据
        content = reader.read()
        
        # 分词
        content = jieba.cut(content)
        
        # 合并结果
        result = ' '.join(content)
        
        # 结果输出
        writer.write(result)
print("Done!!!")
# Out:
# Done!!!

# %% [markdown]
# ## 二、Gensim Word2Vec构建

# %% [markdown]
# #### 训练方式一

# %%
print(f"针对低频词 -> 删除概率:{max(1 - np.sqrt(0.0001 / 0.0000001), 0)}")
print(f"针对低频词 -> 删除概率:{max(1 - np.sqrt(0.0001 / 0.0001), 0)}")
print(f"针对高频词 -> 删除概率:{max(1 - np.sqrt(0.0001 / 0.00011), 0)}")
print(f"针对高频词 -> 删除概率:{max(1 - np.sqrt(0.0001 / 0.0002), 0)}")
print(f"针对高频词 -> 删除概率:{max(1 - np.sqrt(0.0001 / 0.02), 0)}")
# Out:
# 针对低频词 -> 删除概率:0
# 针对低频词 -> 删除概率:0.0
# 针对高频词 -> 删除概率:0.04653741075440765
# 针对高频词 -> 删除概率:0.2928932188134524
# 针对高频词 -> 删除概率:0.9292893218813453

# %% [markdown]
# ![image.png](attachment:a7a77a12-9ee5-49ab-b8fe-774aa64d4b9c.png)

# %%
# 每行数据加载
print(f"文件路径:{word_file_path}")
sentences = word2vec.LineSentence(word_file_path) 

# 训练Word2Vec模型
"""
class gensim.models.word2vec.Word2Vec(
    sentences=None, corpus_file=None, 
    vector_size=100, alpha=0.025, window=5, min_count=5, max_vocab_size=None, 
    sample=0.001, seed=1, workers=3, min_alpha=0.0001, 
    sg=0, hs=0, negative=5, ns_exponent=0.75, cbow_mean=1, 
    hashfxn=<built-in function hash>, epochs=5, 
    null_word=0, trim_rule=None, sorted_vocab=1, 
    batch_words=10000, compute_loss=False, 
    callbacks=(), comment=None, max_final_vocab=None, shrink_windows=True)

sentences=None,  给定训练数据对应的对象
corpus_file=None, 词汇表对应的文件，如果不给定的话，直接采用训练数据构建词典/词汇表
vector_size=100, 期望单词映射的维度大小
alpha=0.025, 学习率
window=5, 窗口大小，窗口大小 = 周边词 + 1
min_count=5, 针对词频小于5的单词直接删除    
sample: 0.001 二次重采样时候的系数t
sg=0, 0表示CBOW、1表示Skip-Gram
hs=0, 0表示负采样 1表示哈夫曼树(层次Softmax)
negative=5, 仅在hs=0的时候生效，负采样的类别数量；当设定为0的时候，表示不进行负采样
ns_exponent=0.75, 负采样过程中，计算词频过程中的系数
cbow_mean=1, 0表示cbow中求和，1表示cbow中求均值

"""
model = word2vec.Word2Vec(sentences,sg=1, hs = 1,min_count = 1,window = 11,vector_size = 100)
# Out:
# 2025-01-10 23:24:07,631 : INFO : collecting all words and their counts
# 2025-01-10 23:24:07,635 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2025-01-10 23:24:07,702 : INFO : collected 17794 word types from a corpus of 161063 raw words and 2311 sentences
# 2025-01-10 23:24:07,703 : INFO : Creating a fresh vocabulary
# 2025-01-10 23:24:07,762 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=1 retains 17794 unique words (100.00% of original 17794, drops 0)', 'datetime': '2025-01-10T23:24:07.762553', 'gensim': '4.2.0', 'python': '3.8.19 (default, Mar 20 2024, 19:55:45) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'prepare_vocab'}
# 2025-01-10 23:24:07,762 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=1 leaves 161063 word corpus (100.00% of original 161063, drops 0)', 'datetime': '2025-01-10T23:24:07.762553', 'gensim': '4.2.0', 'python': '3.8.19 (default, Mar 20 2024, 19:55:45) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'prepare_vocab'}
# 2025-01-10 23:24:07,819 : INFO : deleting the raw counts dictionary of 17794 items
# 文件路径:./datas/cut_words_of_in_the_name_of_people.txt
# 2025-01-10 23:24:07,820 : INFO : sample=0.001 downsamples 38 most-common words
# 2025-01-10 23:24:07,821 : INFO : Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 120245.36592399672 word corpus (74.7%% of prior 161063)', 'datetime': '2025-01-10T23:24:07.821644', 'gensim': '4.2.0', 'python': '3.8.19 (default, Mar 20 2024, 19:55:45) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'prepare_vocab'}
# 2025-01-10 23:24:07,825 : INFO : constructing a huffman tree from 17794 words
# 2025-01-10 23:24:08,373 : INFO : built huffman tree with maximum node depth 17
# 2025-01-10 23:24:08,509 : INFO : estimated required memory for 17794 words and 100 dimensions: 33808600 bytes
# 2025-01-10 23:24:08,509 : INFO : resetting layer weights
# 2025-01-10 23:24:08,517 : INFO : Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2025-01-10T23:24:08.517070', 'gensim': '4.2.0', 'python': '3.8.19 (default, Mar 20 2024, 19:55:45) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'build_vocab'}
# 2025-01-10 23:24:08,517 : INFO : Word2Vec lifecycle event {'msg': 'training model with 3 workers on 17794 vocabulary and 100 features, using sg=1 hs=1 sample=0.001 negative=5 window=11 shrink_windows=True', 'datetime': '2025-01-10T23:24:08.517070', 'gensim': '4.2.0', 'python': '3.8.19 (default, Mar 20 2024, 19:55:45) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'train'}
# 2025-01-10 23:24:09,263 : INFO : EPOCH 0: training on 161063 raw words (120295 effective words) took 0.7s, 161772 effective words/s
# 2025-01-10 23:24:09,985 : INFO : EPOCH 1: training on 161063 raw words (120348 effective words) took 0.7s, 167355 effective words/s
# 2025-01-10 23:24:10,811 : INFO : EPOCH 2: training on 161063 raw words (120468 effective words) took 0.8s, 146369 effective words/s
# 2025-01-10 23:24:11,838 : INFO : EPOCH 3 - PROGRESS: at 100.00% examples, 117824 words/s, in_qsize 0, out_qsize 1
# 2025-01-10 23:24:11,840 : INFO : EPOCH 3: training on 161063 raw words (120344 effective words) took 1.0s, 117540 effective words/s
# 2025-01-10 23:24:12,918 : INFO : EPOCH 4 - PROGRESS: at 100.00% examples, 112099 words/s, in_qsize 0, out_qsize 1
# 2025-01-10 23:24:12,922 : INFO : EPOCH 4: training on 161063 raw words (120413 effective words) took 1.1s, 111708 effective words/s
# 2025-01-10 23:24:12,925 : INFO : Word2Vec lifecycle event {'msg': 'training on 805315 raw words (601868 effective words) took 4.4s, 136544 effective words/s', 'datetime': '2025-01-10T23:24:12.925985', 'gensim': '4.2.0', 'python': '3.8.19 (default, Mar 20 2024, 19:55:45) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'train'}
# 2025-01-10 23:24:12,929 : INFO : Word2Vec lifecycle event {'params': 'Word2Vec<vocab=17794, vector_size=100, alpha=0.025>', 'datetime': '2025-01-10T23:24:12.929982', 'gensim': '4.2.0', 'python': '3.8.19 (default, Mar 20 2024, 19:55:45) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'created'}

# %% [markdown]
# #### 训练方式二

# %%
# 每行数据加载
sentences = word2vec.LineSentence(word_file_path) 

# 创建Word2Vec模型
model = word2vec.Word2Vec(hs = 1,min_count = 1,window = 5,vector_size = 100)

# 构建词典
model.build_vocab(sentences)

# 模型训练
model.train(sentences, total_examples=model.corpus_count, epochs=5)
# Out:
# 2025-01-10 23:24:12,971 : INFO : Word2Vec lifecycle event {'params': 'Word2Vec<vocab=0, vector_size=100, alpha=0.025>', 'datetime': '2025-01-10T23:24:12.971995', 'gensim': '4.2.0', 'python': '3.8.19 (default, Mar 20 2024, 19:55:45) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'created'}
# 2025-01-10 23:24:12,991 : INFO : collecting all words and their counts
# 2025-01-10 23:24:12,996 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2025-01-10 23:24:13,079 : INFO : collected 17794 word types from a corpus of 161063 raw words and 2311 sentences
# 2025-01-10 23:24:13,081 : INFO : Creating a fresh vocabulary
# 2025-01-10 23:24:13,214 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=1 retains 17794 unique words (100.00% of original 17794, drops 0)', 'datetime': '2025-01-10T23:24:13.214992', 'gensim': '4.2.0', 'python': '3.8.19 (default, Mar 20 2024, 19:55:45) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'prepare_vocab'}
# 2025-01-10 23:24:13,217 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=1 leaves 161063 word corpus (100.00% of original 161063, drops 0)', 'datetime': '2025-01-10T23:24:13.217079', 'gensim': '4.2.0', 'python': '3.8.19 (default, Mar 20 2024, 19:55:45) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'prepare_vocab'}
# 2025-01-10 23:24:13,531 : INFO : deleting the raw counts dictionary of 17794 items
# 2025-01-10 23:24:13,533 : INFO : sample=0.001 downsamples 38 most-common words
# 2025-01-10 23:24:13,534 : INFO : Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 120245.36592399672 word corpus (74.7%% of prior 161063)', 'datetime': '2025-01-10T23:24:13.534183', 'gensim': '4.2.0', 'python': '3.8.19 (default, Mar 20 2024, 19:55:45) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'prepare_vocab'}
# 2025-01-10 23:24:13,542 : INFO : constructing a huffman tree from 17794 words
# 2025-01-10 23:24:14,431 : INFO : built huffman tree with maximum node depth 17
# 2025-01-10 23:24:14,731 : INFO : estimated required memory for 17794 words and 100 dimensions: 33808600 bytes
# 2025-01-10 23:24:14,732 : INFO : resetting layer weights
# 2025-01-10 23:24:14,744 : INFO : Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2025-01-10T23:24:14.744235', 'gensim': '4.2.0', 'python': '3.8.19 (default, Mar 20 2024, 19:55:45) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'build_vocab'}
# 2025-01-10 23:24:14,745 : INFO : Word2Vec lifecycle event {'msg': 'training model with 3 workers on 17794 vocabulary and 100 features, using sg=0 hs=1 sample=0.001 negative=5 window=5 shrink_windows=True', 'datetime': '2025-01-10T23:24:14.745326', 'gensim': '4.2.0', 'python': '3.8.19 (default, Mar 20 2024, 19:55:45) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'train'}
# 2025-01-10 23:24:14,963 : INFO : EPOCH 0: training on 161063 raw words (120365 effective words) took 0.2s, 562796 effective words/s
# 2025-01-10 23:24:15,133 : INFO : EPOCH 1: training on 161063 raw words (120281 effective words) took 0.2s, 723534 effective words/s
# 2025-01-10 23:24:15,350 : INFO : EPOCH 2: training on 161063 raw words (120071 effective words) took 0.2s, 563965 effective words/s
# 2025-01-10 23:24:15,529 : INFO : EPOCH 3: training on 161063 raw words (120284 effective words) took 0.2s, 686088 effective words/s
# 2025-01-10 23:24:15,733 : INFO : EPOCH 4: training on 161063 raw words (120274 effective words) took 0.2s, 603901 effective words/s
# 2025-01-10 23:24:15,734 : INFO : Word2Vec lifecycle event {'msg': 'training on 805315 raw words (601275 effective words) took 1.0s, 608443 effective words/s', 'datetime': '2025-01-10T23:24:15.734548', 'gensim': '4.2.0', 'python': '3.8.19 (default, Mar 20 2024, 19:55:45) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'train'}
# (601275, 805315)

# %% [markdown]
# ## 三、Word2Vec应用

# %% [markdown]
# ### 0. 获取Word2Vec模型相关属性

# %%
print("【词汇数目】: {}".format(len(model.wv.key_to_index)))
print("【转换的稠密的特征向量维度数目,每个单词转换的向量维度大小】: {}".format(model.wv.vector_size))
print("【单词到id的映射关系】: \n{}".format(model.wv.key_to_index))
# Out:
# 【词汇数目】: 17794
# 【转换的稠密的特征向量维度数目,每个单词转换的向量维度大小】: 100
# 【单词到id的映射关系】:
# {'，': 0, '的': 1, '。': 2, '了': 3, '！': 4, '：': 5, '？': 6, '是': 7, '他': 8, '我': 9, '你': 10, '说': 11, '侯亮平': 12, '在': 13, '也': 14, '就': 15, '…': 16, '和': 17, '啊': 18, '不': 19, '李达康': 20, '这': 21, '有': 22, '着': 23, '都': 24, '高育良': 25, '祁同伟': 26, '把': 27, '蔡成功': 28, '让': 29, '老师': 30, '要': 31, '还': 32, '—': 33, '上': 34, '又': 35, '一个': 36, '吧': 37, '书记': 38, '呢': 39, '到': 40, '吗': 41, '没': 42, '对': 43, '人': 44, '地': 45, '沙瑞金': 46, '得': 47, '给': 48, '、': 49, '她': 50, '高小琴': 51, '就是': 52, '我们': 53, '不是': 54, '知道': 55, '这个': 56, '去': 57, '很': 58, '来': 59, '陈海': 60, '丁义珍': 61, '自己': 62, '现在': 63, '好': 64, '陆亦可': 65, '同志': 66, '欧阳菁': 67, '想': 68, '他们': 69, '那': 70, '啥': 71, '季昌明': 72, '道': 73, '这么': 74, '被': 75, '怎么': 76, '您': 77, '高': 78, '局长': 79, '会': 80, '嘛': 81, '你们': 82, '能': 83, '但': 84, '做': 85, '起来': 86, '没有': 87, '谁': 88, '什么': 89, '一': 90, '走': 91, '向': 92, '看': 93, '过': 94, '还是': 95, '却': 96, '大风': 97, '可': 98, '里': 99, '问题': 100, '从': 101, '时': 102, '陈岩石': 103, '大': 104, '刘新建': 105, '事': 106, '今天': 107, '集团': 108, '下': 109, '问': 110, '汇报': 111, '这位': 112, '情况': 113, '山水': 114, '郑西坡': 115, '厂': 116, '赵瑞龙': 117, '再': 118, '不能': 119, '电话': 120, '找': 121, '举报': 122, '个': 123, '为': 124, '像': 125, '赵东来': 126, '有些': 127, '老': 128, '一下': 129, '干部': 130, '们': 131, '已经': 132, '易学习': 133, '才': 134, '检察院': 135, '这样': 136, '后': 137, '看着': 138, '京州': 139, '中': 140, '还有': 141, '是不是': 142, '与': 143, '可能': 144, '”': 145, '学生': 146, '出': 147, '“': 148, '前': 149, '不会': 150, '哎': 151, '领导': 152, '这种': 153, '工作': 154, '如果': 155, 'H省': 156, '呀': 157, '反贪局': 158, '手机': 159, '这时': 160, '工人': 161, '厅长': 162, '过来': 163, '赵立春': 164, '可以': 165, '请': 166, '北京': 167, '这些': 168, '新': 169, '多': 170, '光明': 171, '省委': 172, '这是': 173, '听': 174, '地说': 175, '应该': 176, '便': 177, '省委书记': 178, '叫': 179, '亮平': 180, '所以': 181, '儿子': 182, '笑': 183, '小': 184, '真': 185, '拿': 186, '股权': 187, '打': 188, '吴': 189, '明白': 190, '出来': 191, '人家': 192, '那个': 193, '搞': 194, '会计': 195, '站': 196, '王大路': 197, '太': 198, '孙连城': 199, '话': 200, '一位': 201, '这里': 202, '陈清泉': 203, '一直': 204, '等': 205, '起': 206, '政治': 207, '肖钢玉': 208, '吴慧芬': 209, '并': 210, '张': 211, '跑': 212, '更': 213, '审讯': 214, '而': 215, '吃': 216, '省': 217, '侯': 218, '当年': 219, '别': 220, '用': 221, '马上': 222, '办公室': 223, '尤': 224, '干': 225, '抓': 226, '心里': 227, '那么': 228, '处长': 229, '总': 230, '面前': 231, '一起': 232, '咱们': 233, '以': 234, '正': 235, '将': 236, '意外': 237, '觉得': 238, '开始': 239, '钱': 240, '当': 241, '死': 242, '一些': 243, '两个': 244, '警察': 245, '达康': 246, '李': 247, '当然': 248, '证据': 249, '倒': 250, '关系': 251, '发现': 252, '希望': 253, '喝': 254, '不要': 255, '离婚': 256, '突然': 257, '因为': 258, '公安局': 259, '一样': 260, '告诉': 261, '该': 262, '送': 263, '已': 264, '讲': 265, '只': 266, '秘书': 267, '立即': 268, '最': 269, '清楚': 270, '竟然': 271, '田国富': 272, '刘庆祝': 273, '沙': 274, '副': 275, '办': 276, '一张': 277, '银行': 278, '大家': 279, '一次': 280, '公安厅': 281, '妻子': 282, '也许': 283, '老婆': 284, '市': 285, '多少': 286, '当时': 287, '吕州': 288, '人民': 289, '发生': 290, '彩霞': 291, '既然': 292, '照片': 293, '先': 294, '谈': 295, '王': 296, '注意': 297, '警车': 298, '怕': 299, '猴子': 300, '赵德汉': 301, '政府': 302, '看看': 303, '市委书记': 304, '哦': 305, '坐下': 306, '只有': 307, '但是': 308, '准备': 309, '跟': 310, '安排': 311, '一场': 312, '为了': 313, '有人': 314, '肯定': 315, '及时': 316, '的话': 317, '以后': 318, '文革': 319, '下来': 320, '似乎': 321, '九一六': 322, '有个': 323, '必须': 324, '成': 325, '回来': 326, '湖': 327, '公司': 328, '仍': 329, '手': 330, '其实': 331, '眼睛': 332, '不知': 333, '钟小艾': 334, '仿佛': 335, '发小': 336, '开': 337, '点': 338, '了解': 339, '最后': 340, '家': 341, '见': 342, '继续': 343, '一定': 344, '不过': 345, '甚至': 346, '既': 347, '事情': 348, '比': 349, '不想': 350, '祁': 351, '这才': 352, '罢': 353, '政法系': 354, '咱': 355, '秦': 356, '几个': 357, '脸': 358, '实在': 359, '重要': 360, '拆迁': 361, '心中': 362, '带': 363, '组织': 364, '而且': 365, '事件': 366, '作为': 367, '一片': 368, '多年': 369, '检察长': 370, '住': 371, '对手': 372, '好好': 373, '时间': 374, '只要': 375, '项目': 376, '老人': 377, '群众': 378, '过去': 379, '亲自': 380, '回': 381, '摇头': 382, '林城': 383, '不好': 384,  ...

# %% [markdown]
# ### 1. 获取相似度最高的K个演员

# %%
# 夹角余弦相似度
req_count = 10
for (word, sim) in model.wv.similar_by_word('沙瑞金', topn =100):
    if len(word)==3:  # 为了过滤一下
        req_count -= 1
        print(word, sim)
        if req_count == 0:
            break;
# Out:
# 高育良 0.9590117335319519
# 田国富 0.9532232880592346
# 易学习 0.9157365560531616
# 侯亮平 0.9022494554519653
# 祁同伟 0.8982030153274536
# 李达康 0.8912221789360046
# 季昌明 0.8854848742485046
# 孙书记 0.8807753920555115
# 检察长 0.8706597089767456
# 陈岩石 0.8696175217628479

# %%
# 夹角余弦相似度
req_count = 10
for (word, sim) in model.wv.similar_by_word('沙瑞金', topn =100):
    if len(word)==4:  # 为了过滤一下
        req_count -= 1
        print(word, sim)
        if req_count == 0:
            break;
# Out:
# 直截了当 0.9075130820274353
# 深思熟虑 0.883637011051178
# 不好意思 0.8741983771324158
# 近在咫尺 0.8511180877685547
# 摇头叹息 0.8481922745704651

# %%
import jieba.posseg as pseg

jieba.add_word('沙瑞金',10,'nr')
jieba.add_word('田国富',10,'nr')
jieba.add_word('高育良',10,'nr')
jieba.add_word('侯亮平',10,'nr')
jieba.add_word('钟小艾', 10,'nr')
jieba.add_word('陈岩石', 10,'nr')
jieba.add_word('欧阳菁', 10,'nr')
jieba.add_word('易学习', 10,'nr')
jieba.add_word('王大路', 10,'nr')
jieba.add_word('蔡成功', 10,'nr')
jieba.add_word('孙连城', 10,'nr')
jieba.add_word('季昌明', 10,'nr')
jieba.add_word('丁义珍', 10,'nr')
jieba.add_word('郑西坡', 10,'nr')
jieba.add_word('赵东来', 10,'nr')
jieba.add_word('高小琴', 10,'nr')
jieba.add_word('赵瑞龙', 10,'nr')
jieba.add_word('林华华', 10,'nr')
jieba.add_word('陆亦可', 10,'nr')
jieba.add_word('刘新建', 10,'nr')
jieba.add_word('刘庆祝', 10,'nr')
jieba.add_word('京州市', 10,'nr')
jieba.add_word('副市长', 10,'nr')
jieba.add_word('赵德汉',10,'nr')


tmp01 = model.wv.similar_by_word('沙瑞金', topn=100)
tmp01 = dict(tmp01)
for k in tmp01.keys():
    jieba.suggest_freq(k, True)
tmp02 = ' '.join(list(tmp01.keys()))
words = pseg.lcut(tmp02)
for word,flag in words:
    if flag == 'nr':
        print(word, tmp01[word])
# Out:
# 高育良 0.9590117335319519
# 田国富 0.9532232880592346
# 易学习 0.9157365560531616
# 侯亮平 0.9022494554519653
# 季昌明 0.8854848742485046
# 孙书记 0.8807753920555115
# 陈岩石 0.8696175217628479
# 陆亦可 0.8621822595596313
# 赵东来 0.8556560277938843
# 钟小艾 0.8518775105476379

# %% [markdown]
# ### 2. 获取单词之间的相似度

# %%
# 夹角余弦相似度
print(model.wv.similarity('沙瑞金', '高育良'))
# Out:
# 0.95901173

# %% [markdown]
# ### 3. 获取单词的词向量

# %%
v1 = model.wv.get_vector("提拔")
print(v1.shape)
print(v1)
# Out:
# (100,)
# [ 0.09740067  0.22421603 -0.04097468  0.02196672  0.0935213  -0.23833922
#   0.08993759  0.15319072  0.03314243 -0.08197603 -0.06162888 -0.05316175
#   0.08284175  0.01468705  0.1329021  -0.10488618  0.06305634 -0.24348857
#  -0.07886045 -0.01883138  0.07694464 -0.04275147 -0.08444106 -0.1274649
#  -0.0459091  -0.13082416 -0.08875924 -0.09454681 -0.15151569  0.18529694
#   0.1829651  -0.0324772   0.11817569 -0.04741367 -0.01555066  0.1256406
#  -0.04715392 -0.05944826  0.09952636 -0.10895291 -0.11365729 -0.00967365
#  -0.05056324 -0.09813625  0.04341048 -0.16095683  0.19057778 -0.03151514
#  -0.20048265  0.08827771  0.16105142 -0.13932313 -0.01504623 -0.13246486
#  -0.11945024  0.08294129  0.05444674  0.05619821 -0.06597403  0.07536127
#  -0.06107453 -0.04330957 -0.07126736 -0.09668513 -0.01488112 -0.00133136
#   0.05793112  0.17038281 -0.25681064  0.01020984 -0.04974748 -0.04319508
#   0.05164963 -0.06779381  0.0197491  -0.02662527 -0.00400715 -0.00185036
#  -0.05804006  0.07401925 -0.00126817 -0.07644751 -0.07584637  0.19282979
#   0.07248228  0.05614993  0.16720356  0.16561309  0.20297065  0.15042794
#   0.16249216  0.11335295  0.00559073  0.03064296  0.19296382  0.0256812
#  -0.00163512 -0.20434201  0.10825907 -0.05349217]

# %%
model.wv['提拔']
# Out:
# array([ 0.09740067,  0.22421603, -0.04097468,  0.02196672,  0.0935213 ,
#        -0.23833922,  0.08993759,  0.15319072,  0.03314243, -0.08197603,
#        -0.06162888, -0.05316175,  0.08284175,  0.01468705,  0.1329021 ,
#        -0.10488618,  0.06305634, -0.24348857, -0.07886045, -0.01883138,
#         0.07694464, -0.04275147, -0.08444106, -0.1274649 , -0.0459091 ,
#        -0.13082416, -0.08875924, -0.09454681, -0.15151569,  0.18529694,
#         0.1829651 , -0.0324772 ,  0.11817569, -0.04741367, -0.01555066,
#         0.1256406 , -0.04715392, -0.05944826,  0.09952636, -0.10895291,
#        -0.11365729, -0.00967365, -0.05056324, -0.09813625,  0.04341048,
#        -0.16095683,  0.19057778, -0.03151514, -0.20048265,  0.08827771,
#         0.16105142, -0.13932313, -0.01504623, -0.13246486, -0.11945024,
#         0.08294129,  0.05444674,  0.05619821, -0.06597403,  0.07536127,
#        -0.06107453, -0.04330957, -0.07126736, -0.09668513, -0.01488112,
#        -0.00133136,  0.05793112,  0.17038281, -0.25681064,  0.01020984,
#        -0.04974748, -0.04319508,  0.05164963, -0.06779381,  0.0197491 ,
#        -0.02662527, -0.00400715, -0.00185036, -0.05804006,  0.07401925,
#        -0.00126817, -0.07644751, -0.07584637,  0.19282979,  0.07248228,
#         0.05614993,  0.16720356,  0.16561309,  0.20297065,  0.15042794,
#         0.16249216,  0.11335295,  0.00559073,  0.03064296,  0.19296382,
#         0.0256812 , -0.00163512, -0.20434201,  0.10825907, -0.05349217],
#       dtype=float32)

# %%
# 异常：不存在"小明"这个单词
# model.wv.get_vector("小明")

# %%
# 首先判断是否存在单词，如果存在，就返回，否则单词直接过滤
word = "小明"
#word = "李达康"
if word in model.wv:
    print("【向量】:\n{}".format(model.wv[word]))
else:
    print("【单词不存在】!!!")
# Out:
# 【单词不存在】!!!

# %% [markdown]
# ## 四、模型持久化&模型恢复加载

# %% [markdown]
# ### 方式一：
# 直接使用save API进行模型持久化

# %% [markdown]
# #### 持久化

# %%
model.save(model_file_path1)
# Out:
# 2025-01-10 23:24:16,047 : INFO : Word2Vec lifecycle event {'fname_or_handle': './datas/gensim_word2vec1.w2v', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2025-01-10T23:24:16.047212', 'gensim': '4.2.0', 'python': '3.8.19 (default, Mar 20 2024, 19:55:45) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'saving'}
# 2025-01-10 23:24:16,051 : INFO : not storing attribute cum_table
# 2025-01-10 23:24:16,317 : INFO : saved ./datas/gensim_word2vec1.w2v

# %% [markdown]
# #### 加载

# %%
# 直接基于路径加载
model1 = word2vec.Word2Vec.load(model_file_path1)
print(model1)

v1 = model1.wv.get_vector("提拔")
print(v1.shape)
print(v1)
# Out:
# 2025-01-10 23:24:16,340 : INFO : loading Word2Vec object from ./datas/gensim_word2vec1.w2v
# 2025-01-10 23:24:16,432 : INFO : loading wv recursively from ./datas/gensim_word2vec1.w2v.wv.* with mmap=None
# 2025-01-10 23:24:16,433 : INFO : setting ignored attribute cum_table to None
# 2025-01-10 23:24:16,753 : INFO : Word2Vec lifecycle event {'fname': './datas/gensim_word2vec1.w2v', 'datetime': '2025-01-10T23:24:16.753289', 'gensim': '4.2.0', 'python': '3.8.19 (default, Mar 20 2024, 19:55:45) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'loaded'}
# Word2Vec<vocab=17794, vector_size=100, alpha=0.025>
# (100,)
# [ 0.09740067  0.22421603 -0.04097468  0.02196672  0.0935213  -0.23833922
#   0.08993759  0.15319072  0.03314243 -0.08197603 -0.06162888 -0.05316175
#   0.08284175  0.01468705  0.1329021  -0.10488618  0.06305634 -0.24348857
#  -0.07886045 -0.01883138  0.07694464 -0.04275147 -0.08444106 -0.1274649
#  -0.0459091  -0.13082416 -0.08875924 -0.09454681 -0.15151569  0.18529694
#   0.1829651  -0.0324772   0.11817569 -0.04741367 -0.01555066  0.1256406
#  -0.04715392 -0.05944826  0.09952636 -0.10895291 -0.11365729 -0.00967365
#  -0.05056324 -0.09813625  0.04341048 -0.16095683  0.19057778 -0.03151514
#  -0.20048265  0.08827771  0.16105142 -0.13932313 -0.01504623 -0.13246486
#  -0.11945024  0.08294129  0.05444674  0.05619821 -0.06597403  0.07536127
#  -0.06107453 -0.04330957 -0.07126736 -0.09668513 -0.01488112 -0.00133136
#   0.05793112  0.17038281 -0.25681064  0.01020984 -0.04974748 -0.04319508
#   0.05164963 -0.06779381  0.0197491  -0.02662527 -0.00400715 -0.00185036
#  -0.05804006  0.07401925 -0.00126817 -0.07644751 -0.07584637  0.19282979
#   0.07248228  0.05614993  0.16720356  0.16561309  0.20297065  0.15042794
#   0.16249216  0.11335295  0.00559073  0.03064296  0.19296382  0.0256812
#  -0.00163512 -0.20434201  0.10825907 -0.05349217]

# %% [markdown]
# ### 方式二：
# 保存为二进制词向量

# %% [markdown]
# #### 持久化

# %%
model.wv.save_word2vec_format(model_file_path2, binary=True)
# Out:
# 2025-01-10 23:24:16,820 : INFO : storing 17794x100 projection weights into ./datas/gensim_word2vec2.bin

# %% [markdown]
# #### 加载

# %%
# 加载模型
model2 = gensim.models.KeyedVectors.load_word2vec_format(model_file_path2, binary=True)
print(model2)

# 应用模型
v1 = model2.get_vector("提拔")
print(v1.shape)
print(v1)
# Out:
# 2025-01-10 23:24:17,014 : INFO : loading projection weights from ./datas/gensim_word2vec2.bin
# 2025-01-10 23:24:17,321 : INFO : KeyedVectors lifecycle event {'msg': 'loaded (17794, 100) matrix of type float32 from ./datas/gensim_word2vec2.bin', 'binary': True, 'encoding': 'utf8', 'datetime': '2025-01-10T23:24:17.321086', 'gensim': '4.2.0', 'python': '3.8.19 (default, Mar 20 2024, 19:55:45) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'load_word2vec_format'}
# KeyedVectors<vector_size=100, 17794 keys>
# (100,)
# [ 0.09740067  0.22421603 -0.04097468  0.02196672  0.0935213  -0.23833922
#   0.08993759  0.15319072  0.03314243 -0.08197603 -0.06162888 -0.05316175
#   0.08284175  0.01468705  0.1329021  -0.10488618  0.06305634 -0.24348857
#  -0.07886045 -0.01883138  0.07694464 -0.04275147 -0.08444106 -0.1274649
#  -0.0459091  -0.13082416 -0.08875924 -0.09454681 -0.15151569  0.18529694
#   0.1829651  -0.0324772   0.11817569 -0.04741367 -0.01555066  0.1256406
#  -0.04715392 -0.05944826  0.09952636 -0.10895291 -0.11365729 -0.00967365
#  -0.05056324 -0.09813625  0.04341048 -0.16095683  0.19057778 -0.03151514
#  -0.20048265  0.08827771  0.16105142 -0.13932313 -0.01504623 -0.13246486
#  -0.11945024  0.08294129  0.05444674  0.05619821 -0.06597403  0.07536127
#  -0.06107453 -0.04330957 -0.07126736 -0.09668513 -0.01488112 -0.00133136
#   0.05793112  0.17038281 -0.25681064  0.01020984 -0.04974748 -0.04319508
#   0.05164963 -0.06779381  0.0197491  -0.02662527 -0.00400715 -0.00185036
#  -0.05804006  0.07401925 -0.00126817 -0.07644751 -0.07584637  0.19282979
#   0.07248228  0.05614993  0.16720356  0.16561309  0.20297065  0.15042794
#   0.16249216  0.11335295  0.00559073  0.03064296  0.19296382  0.0256812
#  -0.00163512 -0.20434201  0.10825907 -0.05349217]

# %%
# 加载模型
model2 = gensim.models.KeyedVectors.load_word2vec_format('./datas/vectors.bin',
                                                         binary=True)
print(model2)

# 应用模型
v1 = model2.get_vector("酒店")
print(v1.shape)
print(v1)
# Out:
# 2025-01-10 23:24:17,345 : INFO : loading projection weights from ./datas/vectors.bin
# 2025-01-10 23:24:17,473 : INFO : KeyedVectors lifecycle event {'msg': 'loaded (7942, 128) matrix of type float32 from ./datas/vectors.bin', 'binary': True, 'encoding': 'utf8', 'datetime': '2025-01-10T23:24:17.473224', 'gensim': '4.2.0', 'python': '3.8.19 (default, Mar 20 2024, 19:55:45) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'load_word2vec_format'}
# KeyedVectors<vector_size=128, 7942 keys>
# (128,)
# [ 0.07507085 -0.06233635 -0.08300601 -0.09476656  0.19525695  0.08683676
#   0.267884    0.03470918  0.14521684  0.00294149 -0.02735998 -0.09170757
#   0.00139181  0.2421832  -0.09511401  0.0341509   0.0283838   0.32073992
#   0.172025    0.20465788  0.05929533  0.07462119 -0.23834492  0.0421031
#  -0.0448295  -0.02866336  0.05001667 -0.1257836   0.22431172 -0.0807058
#  -0.12493779 -0.05265829  0.13126895  0.15061386 -0.19615541 -0.09053446
#  -0.05627611 -0.23135136 -0.01231913 -0.23680945 -0.04299964  0.3667591
#  -0.06821534 -0.29599202  0.34265348 -0.04311483 -0.21866152 -0.2495054
#  -0.43372962  0.0463162   0.11516414  0.07433167  0.09803177 -0.06165684
#  -0.1319202   0.04795204  0.2651979   0.09628078 -0.16381025  0.12577897
#   0.11097272 -0.15810862 -0.07860032  0.08296187  0.12618895  0.28030068
#  -0.00506122  0.05640052  0.11889897 -0.11027029 -0.14830197 -0.00842615
#   0.01188814  0.19347009  0.00282715 -0.3220406   0.22365303 -0.23093392
#  -0.41848904 -0.19116873 -0.12905827  0.29085568 -0.33723694 -0.21085052
#   0.04453738 -0.07304095 -0.0262253   0.19612503  0.33479366  0.14669509
#   0.12059527 -0.00447296 -0.05844707  0.08822253  0.0886934   0.03672414
#   0.03962974  0.18999839  0.18470356  0.01651068  0.06237809  0.31986848
#   0.07099832  0.08987687  0.03214902 -0.0823281  -0.18802191  0.02356046
#  -0.05299398 -0.01493336  0.14630602 -0.06124404  0.08387742 -0.11301316
#   0.26206592 -0.05086057 -0.15222454  0.22112454 -0.11467611  0.13941425
#   0.08904102  0.13969192  0.1377303   0.15661885  0.14377183  0.05035875
#   0.11127736  0.24495345]

# %% [markdown]
# ### 方式三：
# 直接使用NumPy API保存词向量信息

# %% [markdown]
# #### 持久化

# %%
# 获取词向量
norm_word_embeddings = model.wv.get_normed_vectors()  # L2-norm归一化转换后的单词向量
word_embeddings = model.wv.vectors  # 归一化转换前的单词向量
# 获取词典(词典到idx的映射)
vocab_2_index = list(map(lambda k: (k, model.wv.key_to_index[k]), model.wv.key_to_index))
print(np.shape(norm_word_embeddings), np.shape(word_embeddings), np.shape(vocab_2_index))
# 数据保存
np.save(model_file_path3.format("norm_embedding"), norm_word_embeddings)
np.save(model_file_path3.format("embedding"), word_embeddings)
np.save(model_file_path3.format("vocab_2_index"), vocab_2_index)
# Out:
# (17794, 100) (17794, 100) (17794, 2)

# %% [markdown]
# #### 加载

# %%
# 加载数据
norm_word_embeddings = np.load(model_file_path3.format("norm_embedding"))
word_embeddings = np.load(model_file_path3.format("embedding"))
vocab_2_index = np.load(model_file_path3.format("vocab_2_index"))

# 字典转换
vocab_2_index = dict(map(lambda t:(t[0], int(t[1])), vocab_2_index))

# 获取数据
word = "提拔"
index = vocab_2_index[word]
v1 = word_embeddings[index]
print(v1.shape)
print(v1)
# Out:
# (100,)
# [ 0.09740067  0.22421603 -0.04097468  0.02196672  0.0935213  -0.23833922
#   0.08993759  0.15319072  0.03314243 -0.08197603 -0.06162888 -0.05316175
#   0.08284175  0.01468705  0.1329021  -0.10488618  0.06305634 -0.24348857
#  -0.07886045 -0.01883138  0.07694464 -0.04275147 -0.08444106 -0.1274649
#  -0.0459091  -0.13082416 -0.08875924 -0.09454681 -0.15151569  0.18529694
#   0.1829651  -0.0324772   0.11817569 -0.04741367 -0.01555066  0.1256406
#  -0.04715392 -0.05944826  0.09952636 -0.10895291 -0.11365729 -0.00967365
#  -0.05056324 -0.09813625  0.04341048 -0.16095683  0.19057778 -0.03151514
#  -0.20048265  0.08827771  0.16105142 -0.13932313 -0.01504623 -0.13246486
#  -0.11945024  0.08294129  0.05444674  0.05619821 -0.06597403  0.07536127
#  -0.06107453 -0.04330957 -0.07126736 -0.09668513 -0.01488112 -0.00133136
#   0.05793112  0.17038281 -0.25681064  0.01020984 -0.04974748 -0.04319508
#   0.05164963 -0.06779381  0.0197491  -0.02662527 -0.00400715 -0.00185036
#  -0.05804006  0.07401925 -0.00126817 -0.07644751 -0.07584637  0.19282979
#   0.07248228  0.05614993  0.16720356  0.16561309  0.20297065  0.15042794
#   0.16249216  0.11335295  0.00559073  0.03064296  0.19296382  0.0256812
#  -0.00163512 -0.20434201  0.10825907 -0.05349217]

# %% [markdown]
# # 五、扩展：直接从文件中读取数据来进行模型训练

# %%
from gensim import utils
from gensim.models.word2vec import Word2Vec


class MyData(object):
    def __iter__(self):
        path = word_file_path
        with open(path, 'r', encoding='utf-8') as reader:
            for line in reader:
                yield list(utils.tokenize(line))

# 模型构建
model_ = Word2Vec(hs = 1,min_count = 1,window = 5,vector_size = 100, sentences=MyData())
# Out:
# 2025-01-10 23:24:17,676 : INFO : collecting all words and their counts
# 2025-01-10 23:24:17,680 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2025-01-10 23:24:17,834 : INFO : collected 17738 word types from a corpus of 131863 raw words and 2421 sentences
# 2025-01-10 23:24:17,835 : INFO : Creating a fresh vocabulary
# 2025-01-10 23:24:17,932 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=1 retains 17738 unique words (100.00% of original 17738, drops 0)', 'datetime': '2025-01-10T23:24:17.932126', 'gensim': '4.2.0', 'python': '3.8.19 (default, Mar 20 2024, 19:55:45) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'prepare_vocab'}
# 2025-01-10 23:24:17,933 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=1 leaves 131863 word corpus (100.00% of original 131863, drops 0)', 'datetime': '2025-01-10T23:24:17.933126', 'gensim': '4.2.0', 'python': '3.8.19 (default, Mar 20 2024, 19:55:45) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'prepare_vocab'}
# 2025-01-10 23:24:18,095 : INFO : deleting the raw counts dictionary of 17738 items
# 2025-01-10 23:24:18,097 : INFO : sample=0.001 downsamples 40 most-common words
# 2025-01-10 23:24:18,099 : INFO : Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 111056.0714298438 word corpus (84.2%% of prior 131863)', 'datetime': '2025-01-10T23:24:18.099142', 'gensim': '4.2.0', 'python': '3.8.19 (default, Mar 20 2024, 19:55:45) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'prepare_vocab'}
# 2025-01-10 23:24:18,113 : INFO : constructing a huffman tree from 17738 words
# 2025-01-10 23:24:18,825 : INFO : built huffman tree with maximum node depth 17
# 2025-01-10 23:24:19,040 : INFO : estimated required memory for 17738 words and 100 dimensions: 33702200 bytes
# 2025-01-10 23:24:19,043 : INFO : resetting layer weights
# 2025-01-10 23:24:19,052 : INFO : Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2025-01-10T23:24:19.052649', 'gensim': '4.2.0', 'python': '3.8.19 (default, Mar 20 2024, 19:55:45) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'build_vocab'}
# 2025-01-10 23:24:19,052 : INFO : Word2Vec lifecycle event {'msg': 'training model with 3 workers on 17738 vocabulary and 100 features, using sg=0 hs=1 sample=0.001 negative=5 window=5 shrink_windows=True', 'datetime': '2025-01-10T23:24:19.052944', 'gensim': '4.2.0', 'python': '3.8.19 (default, Mar 20 2024, 19:55:45) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'train'}
# 2025-01-10 23:24:19,351 : INFO : EPOCH 0: training on 131863 raw words (111076 effective words) took 0.3s, 376633 effective words/s
# 2025-01-10 23:24:19,704 : INFO : EPOCH 1: training on 131863 raw words (111025 effective words) took 0.3s, 319797 effective words/s
# 2025-01-10 23:24:19,997 : INFO : EPOCH 2: training on 131863 raw words (111073 effective words) took 0.3s, 384843 effective words/s
# 2025-01-10 23:24:20,249 : INFO : EPOCH 3: training on 131863 raw words (111100 effective words) took 0.2s, 448492 effective words/s
# 2025-01-10 23:24:20,549 : INFO : EPOCH 4: training on 131863 raw words (110926 effective words) took 0.3s, 375817 effective words/s
# 2025-01-10 23:24:20,550 : INFO : Word2Vec lifecycle event {'msg': 'training on 659315 raw words (555200 effective words) took 1.5s, 371187 effective words/s', 'datetime': '2025-01-10T23:24:20.550959', 'gensim': '4.2.0', 'python': '3.8.19 (default, Mar 20 2024, 19:55:45) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'train'}
# 2025-01-10 23:24:20,551 : INFO : Word2Vec lifecycle event {'params': 'Word2Vec<vocab=17738, vector_size=100, alpha=0.025>', 'datetime': '2025-01-10T23:24:20.551971', 'gensim': '4.2.0', 'python': '3.8.19 (default, Mar 20 2024, 19:55:45) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'created'}

# %%
# 夹角余弦相似度
req_count = 5
for key in model_.wv.similar_by_word('沙瑞金', topn =100):
    if len(key[0])==3:
        req_count -= 1
        print(key[0], key[1])
        if req_count == 0:
            break;
# Out:
# 高育良 0.9896942377090454
# 侯亮平 0.9768972992897034
# 田国富 0.9713556170463562
# 易学习 0.9692636132240295
# 李达康 0.9688310027122498

# %% [markdown]
# # 六、扩展：可视化

# %%
from sklearn.decomposition import IncrementalPCA    # inital reduction
from sklearn.manifold import TSNE                   # final reduction
import numpy as np                                  # array handling


def reduce_dimensions(model):
    num_dimensions = 2  # final num dimensions (2D, 3D, etc)

    # extract the words & their vectors, as numpy arrays
    #vectors = np.asarray(model.wv.vectors)
    #labels = np.asarray(model.wv.index_to_key)  # fixed-width numpy strings
    vectors = np.asarray(model.wv.vectors)[:1000]
    labels = np.asarray(model.wv.index_to_key)[:1000]  # fixed-width numpy strings
    print(vectors.shape)

    # reduce using t-SNE
    tsne = TSNE(n_components=num_dimensions, random_state=0)
    vectors = tsne.fit_transform(vectors)

    x_vals = [v[0] for v in vectors]
    y_vals = [v[1] for v in vectors]
    return x_vals, y_vals, labels



def plot_with_plotly(x_vals, y_vals, labels, plot_in_notebook=True):
    from plotly.offline import init_notebook_mode, iplot, plot
    import plotly.graph_objs as go

    trace = go.Scatter(x=x_vals, y=y_vals, mode='text', text=labels)
    data = [trace]

    if plot_in_notebook:
        init_notebook_mode(connected=True)
        iplot(data, filename='word-embedding-plot')
    else:
        plot(data, filename='word-embedding-plot.html')


def plot_with_matplotlib(x_vals, y_vals, labels):
    import matplotlib.pyplot as plt
    import random
    
    plt.rcParams["font.sans-serif"]=["SimHei"] #设置字体
    plt.rcParams["axes.unicode_minus"]=False #该语句解决图像中的“-”负号的乱码问题

    random.seed(0)

    plt.figure(figsize=(12, 12))
    plt.scatter(x_vals, y_vals)

    #
    # Label randomly subsampled 25 data points
    #
    indices = list(range(len(labels)))
    selected_indices = random.sample(indices, 100)
    for i in selected_indices:
        plt.annotate(labels[i], (x_vals[i], y_vals[i]))

# %%
x_vals, y_vals, labels = reduce_dimensions(model)
# Out:
# (1000, 100)

# %%
plot_with_matplotlib(x_vals, y_vals, labels)
